# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
# Create a new YOLO model from scratch
model = YOLO()

# Load a pretrained YOLO model (recommended for training)
#model = YOLO('yolov8n.pt')

# Train the model using the 'data.yaml' dataset for 3 epochs
results = model.train(data='data.yaml', epochs=60)

# Perform object detection on an image using the model
# results = model('https://ultralytics.com/images/bus.jpg')

# Export the model to ONNX format
# success = model.export(format='onnx')
# Out:
# New https://pypi.org/project/ultralytics/8.0.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.152 🚀 Python-3.11.3 torch-2.0.1 CPU (Apple M2 Pro)
# ...

# %%
# Evaluate the model's performance on the validation set
# results = model.val()
# !yolo task=detect mode=val model='runs/detect/train/weights/best.pt' data=data.yaml
# Out:
# Ultralytics YOLOv8.0.152 🚀 Python-3.11.3 torch-2.0.1 CPU (Apple M2 Pro)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /Users/lucyvelasco/marine-perception-ai/datasets/train_data/labels
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         11         16    0.00455      0.938      0.474      0.291
# Speed: 2.1ms preprocess, 69.5ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs/detect/val

# %%
#results = model('/content/train_data/images/validation/1667846701.393603.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = model('/content/train_data/images/validation/1667846701.393603.jpg')
#
# File ~/.pyenv/versions/3.11.3/envs/env-marine-ai/lib/python3.11/site-packages/ultralytics/engine/model.py:98, in Model.__call__(self, source, stream, **kwargs)
#      96 def __call__(self, source=None, stream=False, **kwargs):
#      97     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 98     return self.predict(source, stream, **kwargs)
#
# File ~/.pyenv/versions/3.11.3/envs/env-marine-ai/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# ...

# %%
#Test model
# !yolo task=detect mode=predict model='runs/detect/train2/weights/best.pt' conf=0,25 source='predict_img/boat1.jpeg'

# %%
# Export the model to ONNX format
success = model.export(format='onnx')
